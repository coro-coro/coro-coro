# %%
#pip install pyecharts

# %%
import pandas as pd
import numpy as np
import pyecharts

# %%
print("pyecharts version : ", pyecharts.__version__)
# Out:
# pyecharts version :  1.6.2

# %%
data = pd.read_csv('patient_data.csv', engine='python') #옵션 써야 한글 읽힘

# %%
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note  \
# 0  2020-01-20   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국  NaN
# 1  2020-01-24   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국  NaN
# 2  2020-01-26   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국  NaN
# 3  2020-01-27   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국  NaN
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국  NaN
#
#    출생년도  나이
# 0   NaN NaN
# 1   NaN NaN
# 2   NaN NaN
# 3   NaN NaN
# 4   NaN NaN

# %%
data = data.fillna("")
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note  \
# 0  2020-01-20   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국
# 1  2020-01-24   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국
# 2  2020-01-26   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국
# 3  2020-01-27   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국
#
#   출생년도 나이
# 0
# 1
# 2
# 3
# 4

# %%
data.shape
# Out:
# (104, 12)

# %%
from pyecharts.charts import Pie
from pyecharts import options as opts

# %%
# 감염차수 pie plot
degree = list(np.sort(data.degree.unique()))
degree_value = list(data.degree.value_counts().sort_index())

degree_plot = (
    Pie()
    .add("", [list(z) for z in zip(degree, degree_value)])
    .set_colors(["maroon", "firebrick", "orangered", "gray"])
    .set_global_opts(title_opts=opts.TitleOpts(title=""),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}:\n{d}%", font_size = 11)) #d:%, c:명수
)
degree_plot.render('chasu.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\chasu.html'

# %%
degree_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="82e41a9a9f2d4115985cf392c8354305" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_82e41a9a9f2d4115985cf392c8354305 = echarts.init(
#                     document.getElementById('82e41a9a9f2d4115985cf392c8354305'), 'white', {renderer: 'canvas'});
#                 var option_82e41a9a9f2d4115985cf392c8354305 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "maroon",
#         "firebrick",
#         "orangered",
#         "gray"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\ucc28",
#                     "value": 15
#                 },
#                 {
#                     "name": "2\ucc28",
#                     "value": 9
#                 },
#                 {
#                     "name": "3\ucc28",
#                     "value": 5
#                 },
#                 {
#                     "name": "\ud655\uc778 \uc911",
#                     "value": 17
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "fontSize": 11,
#                 "formatter": "{b}:\n{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\ucc28",
#                 "2\ucc28",
#                 "3\ucc28",
#                 "\ud655\uc778 \uc911"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_82e41a9a9f2d4115985cf392c8354305.setOption(option_82e41a9a9f2d4115985cf392c8354305);
#         });
#     </script>

# %%
# 상태별 pie chart
condition = list(np.sort(data.condition.unique()))
condition_value = list(data.condition.value_counts().sort_index())

condition_plot=(
    Pie()
    .add("", [list(z) for z in zip(condition, condition_value)])
    .set_colors(["cornflowerblue", "slategray", "#BDBDBD"])
    .set_global_opts(title_opts=opts.TitleOpts(title="상태(명)"),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%", font_size = 11)) #d:%, c:명수
)
condition_plot.render('status.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\status.html'

# %%
condition_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="721fe75934d54948a639621a74403525" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_721fe75934d54948a639621a74403525 = echarts.init(
#                     document.getElementById('721fe75934d54948a639621a74403525'), 'white', {renderer: 'canvas'});
#                 var option_721fe75934d54948a639621a74403525 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "cornflowerblue",
#         "slategray",
#         "#BDBDBD"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uc785\uc6d0",
#                     "value": 30
#                 },
#                 {
#                     "name": "\ud1f4\uc6d0",
#                     "value": 16
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "fontSize": 11,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uc785\uc6d0",
#                 "\ud1f4\uc6d0"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uc0c1\ud0dc(\uba85)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_721fe75934d54948a639621a74403525.setOption(option_721fe75934d54948a639621a74403525);
#         });
#     </script>

# %%
# 성별 pie chart

sex = list(np.sort(data.sex.unique()))
sex_value = list(data.sex.value_counts().sort_index())

sex_plot = (
    Pie()
    .add("", [list(z) for z in zip(sex, sex_value)])
    .set_colors(["cornflowerblue", "salmon","gray"])
    .set_global_opts(title_opts=opts.TitleOpts(title="성별(명)"),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%", font_size = 11)) #d:%, c:명수
)
sex_plot.render('gend.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\gend.html'

# %%
sex_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3a2a9235ccaa4c659411dc36f90014d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3a2a9235ccaa4c659411dc36f90014d7 = echarts.init(
#                     document.getElementById('3a2a9235ccaa4c659411dc36f90014d7'), 'white', {renderer: 'canvas'});
#                 var option_3a2a9235ccaa4c659411dc36f90014d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "cornflowerblue",
#         "salmon",
#         "gray"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\ub0a8",
#                     "value": 20
#                 },
#                 {
#                     "name": "\uc5ec",
#                     "value": 26
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "fontSize": 11,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\ub0a8",
#                 "\uc5ec"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uc131\ubcc4(\uba85)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3a2a9235ccaa4c659411dc36f90014d7.setOption(option_3a2a9235ccaa4c659411dc36f90014d7);
#         });
#     </script>

# %%
# 감염유형별 pie chart
infection = list(np.sort(data.type.unique()))
infection_value = list(data.type.value_counts().sort_index())

infection_plot = (
    Pie()
    .add("", [list(z) for z in zip(infection, infection_value)])
    .set_colors(['#fc6472', '#f4b2a6', '#eccdb3', '#bcefd0', '#a1e8e4', '#2b8cbe', 'gray', '#23c8b2', '#7f5a7c'])
    .set_global_opts(title_opts=opts.TitleOpts(title=""),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}:\n{d}%", font_size = 11)) #d:%, c:명수
)
infection_plot.render('how.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\how.html'

# %%
infection_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c859268c66894e829d5441b18aebd7f1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c859268c66894e829d5441b18aebd7f1 = echarts.init(
#                     document.getElementById('c859268c66894e829d5441b18aebd7f1'), 'white', {renderer: 'canvas'});
#                 var option_c859268c66894e829d5441b18aebd7f1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#fc6472",
#         "#f4b2a6",
#         "#eccdb3",
#         "#bcefd0",
#         "#a1e8e4",
#         "#2b8cbe",
#         "gray",
#         "#23c8b2",
#         "#7f5a7c"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uae30\ud0c0 \ud574\uc678 \ubc29\ubb38\uc790",
#                     "value": 3
#                 },
#                 {
#                     "name": "\uc6b0\ud55c \uad50\ubbfc",
#                     "value": 3
#                 },
#                 {
#                     "name": "\uc6b0\ud55c \ubc29\ubb38\uc790",
#                     "value": 6
#                 },
#                 {
#                     "name": "\uc77c\uc0c1 \uc811\ucd09\uc790",
#                     "value": 2
#                 },
#                 {
#                     "name": "\uc911\uad6d \ubc29\ubb38\uc790",
#                     "value": 2
#                 },
#                 {
#                     "name": "\uc911\uad6d\uc778 \uad00\uad11\uac1d",
#                     "value": 3
#                 },
#                 {
#                     "name": "\ud655\uc778 \uc911",
#                     "value": 56
#                 },
#                 {
#                     "name": "\ud655\uc9c4\uc790 \uac00\uc871",
#                     "value": 9
#                 },
#                 {
#                     "name": "\ud655\uc9c4\uc790 \uc811\ucd09\uc790",
#                     "value": 20
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "fontSize": 11,
#                 "formatter": "{b}:\n{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uae30\ud0c0 \ud574\uc678 \ubc29\ubb38\uc790",
#                 "\uc6b0\ud55c \uad50\ubbfc",
#                 "\uc6b0\ud55c \ubc29\ubb38\uc790",
#                 "\uc77c\uc0c1 \uc811\ucd09\uc790",
#                 "\uc911\uad6d \ubc29\ubb38\uc790",
#                 "\uc911\uad6d\uc778 \uad00\uad11\uac1d",
#                 "\ud655\uc778 \uc911",
#                 "\ud655\uc9c4\uc790 \uac00\uc871",
#                 "\ud655\uc9c4\uc790 \uc811\ucd09\uc790"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c859268c66894e829d5441b18aebd7f1.setOption(option_c859268c66894e829d5441b18aebd7f1);
#         });
#     </script>

# %%
# 국적별 pie chart
country = list(np.sort(data.country.unique()))
country_value = list(data.country.value_counts().sort_index())

country_plot = (
    Pie()
    .add("", [list(z) for z in zip(country, country_value)])
    .set_colors(['#b09880', '#f0d0c8', 'gray']) 
    .set_global_opts(title_opts=opts.TitleOpts(title="국적(명)"),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%", font_size = 11)) #d:%, c:명수
)
country_plot.render('nat.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\nat.html'

# %%
country_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6d25816d0d504445a889eb52db21a28c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6d25816d0d504445a889eb52db21a28c = echarts.init(
#                     document.getElementById('6d25816d0d504445a889eb52db21a28c'), 'white', {renderer: 'canvas'});
#                 var option_6d25816d0d504445a889eb52db21a28c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#b09880",
#         "#f0d0c8",
#         "gray"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uc911\uad6d",
#                     "value": 6
#                 },
#                 {
#                     "name": "\ud55c\uad6d",
#                     "value": 76
#                 },
#                 {
#                     "name": "\ud655\uc778 \uc911",
#                     "value": 22
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "fontSize": 11,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uc911\uad6d",
#                 "\ud55c\uad6d",
#                 "\ud655\uc778 \uc911"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uad6d\uc801(\uba85)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6d25816d0d504445a889eb52db21a28c.setOption(option_6d25816d0d504445a889eb52db21a28c);
#         });
#     </script>
