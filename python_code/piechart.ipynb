# %%
#pip install pyecharts

# %%
import pandas as pd
import numpy as np
import pyecharts

# %%
print("pyecharts version : ", pyecharts.__version__)
# Out:
# pyecharts version :  1.6.2

# %%
data = pd.read_csv('patient_data.csv', engine='python') #옵션 써야 한글 읽힘

# %%
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note
# 0  2020-01-19   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국  NaN
# 1  2020-01-22   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국  NaN
# 2  2020-01-25   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국  NaN
# 3  2020-01-26   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국  NaN
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국  NaN

# %%
data = data.fillna("")
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note
# 0  2020-01-19   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국
# 1  2020-01-22   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국
# 2  2020-01-25   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국
# 3  2020-01-26   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국

# %%
data.shape
# Out:
# (29, 10)

# %%
from pyecharts.charts import Pie
from pyecharts import options as opts

# 감염차수 pie plot
degree = list(np.sort(data.degree.unique()))
degree_value = list(data.degree.value_counts().sort_index())

degree_plot = (
    Pie()
    .add("", [list(z) for z in zip(degree, degree_value)])
    .set_colors(["maroon", "firebrick", "orangered", "gray"])
    .set_global_opts(title_opts=opts.TitleOpts(title="감염 차수"))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}:\n{d}%")) #d:%, c:명수
)
degree_plot.render()
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\render.html'

# %%
degree_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f43e1d1e05464eca90c5f7e29a4222ca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f43e1d1e05464eca90c5f7e29a4222ca = echarts.init(
#                     document.getElementById('f43e1d1e05464eca90c5f7e29a4222ca'), 'white', {renderer: 'canvas'});
#                 var option_f43e1d1e05464eca90c5f7e29a4222ca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "maroon",
#         "firebrick",
#         "orangered",
#         "gray"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\ucc28",
#                     "value": 15
#                 },
#                 {
#                     "name": "2\ucc28",
#                     "value": 9
#                 },
#                 {
#                     "name": "3\ucc28",
#                     "value": 4
#                 },
#                 {
#                     "name": "\ud655\uc778 \uc911",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "formatter": "{b}:\n{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\ucc28",
#                 "2\ucc28",
#                 "3\ucc28",
#                 "\ud655\uc778 \uc911"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uac10\uc5fc \ucc28\uc218",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f43e1d1e05464eca90c5f7e29a4222ca.setOption(option_f43e1d1e05464eca90c5f7e29a4222ca);
#         });
#     </script>

# %%
# 상태별 pie chart
condition = list(np.sort(data.condition.unique()))
condition_value = list(data.condition.value_counts().sort_index())

condition_plot=(
    Pie()
    .add("", [list(z) for z in zip(condition, condition_value)])
    .set_colors(["cornflowerblue", "slategray"])
    .set_global_opts(title_opts=opts.TitleOpts(title="상태"))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%")) #d:%, c:명수
)
condition_plot.render()
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\render.html'

# %%
condition_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8ebf20819dc74c62915d981c8089b499" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8ebf20819dc74c62915d981c8089b499 = echarts.init(
#                     document.getElementById('8ebf20819dc74c62915d981c8089b499'), 'white', {renderer: 'canvas'});
#                 var option_8ebf20819dc74c62915d981c8089b499 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "cornflowerblue",
#         "slategray"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uc785\uc6d0",
#                     "value": 20
#                 },
#                 {
#                     "name": "\ud1f4\uc6d0",
#                     "value": 9
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uc785\uc6d0",
#                 "\ud1f4\uc6d0"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uc0c1\ud0dc",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8ebf20819dc74c62915d981c8089b499.setOption(option_8ebf20819dc74c62915d981c8089b499);
#         });
#     </script>

# %%
# 성별 pie chart

sex = list(np.sort(data.sex.unique()))
sex_value = list(data.sex.value_counts().sort_index())

sex_plot = (
    Pie()
    .add("", [list(z) for z in zip(sex, sex_value)])
    .set_colors(["cornflowerblue", "salmon"])
    .set_global_opts(title_opts=opts.TitleOpts(title="성별"))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%")) #d:%, c:명수
)
sex_plot.render()
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\render.html'

# %%
sex_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a5dc3eefe8674b92aa547b21aba81f50" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a5dc3eefe8674b92aa547b21aba81f50 = echarts.init(
#                     document.getElementById('a5dc3eefe8674b92aa547b21aba81f50'), 'white', {renderer: 'canvas'});
#                 var option_a5dc3eefe8674b92aa547b21aba81f50 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "cornflowerblue",
#         "salmon"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\ub0a8",
#                     "value": 16
#                 },
#                 {
#                     "name": "\uc5ec",
#                     "value": 13
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\ub0a8",
#                 "\uc5ec"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uc131\ubcc4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a5dc3eefe8674b92aa547b21aba81f50.setOption(option_a5dc3eefe8674b92aa547b21aba81f50);
#         });
#     </script>

# %%
# 감염유형별 pie chart
infection = list(np.sort(data.type.unique()))
infection_value = list(data.type.value_counts().sort_index())

infection_plot = (
    Pie()
    .add("", [list(z) for z in zip(infection, infection_value)])
    .set_colors(['#fc6472', '#f4b2a6', '#eccdb3', '#bcefd0', '#a1e8e4', 'gray', '#23c8b2', '#7f5a7c'])
    .set_global_opts(title_opts=opts.TitleOpts(title="감염유형"),
                    legend_opts=opts.LegendOpts(is_show = False))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}:\n{d}%")) #d:%, c:명수
)
infection_plot.render()
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\render.html'

# %%
infection_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7293867d453547be9104bbc4745c9a54" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7293867d453547be9104bbc4745c9a54 = echarts.init(
#                     document.getElementById('7293867d453547be9104bbc4745c9a54'), 'white', {renderer: 'canvas'});
#                 var option_7293867d453547be9104bbc4745c9a54 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#fc6472",
#         "#f4b2a6",
#         "#eccdb3",
#         "#bcefd0",
#         "#a1e8e4",
#         "gray",
#         "#23c8b2",
#         "#7f5a7c"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uae30\ud0c0 \ud574\uc678 \ubc29\ubb38\uc790",
#                     "value": 3
#                 },
#                 {
#                     "name": "\uc6b0\ud55c \uad50\ubbfc",
#                     "value": 3
#                 },
#                 {
#                     "name": "\uc6b0\ud55c \ubc29\ubb38\uc790",
#                     "value": 6
#                 },
#                 {
#                     "name": "\uc911\uad6d \ubc29\ubb38\uc790",
#                     "value": 2
#                 },
#                 {
#                     "name": "\uc911\uad6d\uc778 \uad00\uad11\uac1d",
#                     "value": 3
#                 },
#                 {
#                     "name": "\ud655\uc778 \uc911",
#                     "value": 1
#                 },
#                 {
#                     "name": "\ud655\uc9c4\uc790 \uac00\uc871",
#                     "value": 8
#                 },
#                 {
#                     "name": "\ud655\uc9c4\uc790 \uc9c0\uc778",
#                     "value": 3
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "formatter": "{b}:\n{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uae30\ud0c0 \ud574\uc678 \ubc29\ubb38\uc790",
#                 "\uc6b0\ud55c \uad50\ubbfc",
#                 "\uc6b0\ud55c \ubc29\ubb38\uc790",
#                 "\uc911\uad6d \ubc29\ubb38\uc790",
#                 "\uc911\uad6d\uc778 \uad00\uad11\uac1d",
#                 "\ud655\uc778 \uc911",
#                 "\ud655\uc9c4\uc790 \uac00\uc871",
#                 "\ud655\uc9c4\uc790 \uc9c0\uc778"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uac10\uc5fc\uc720\ud615",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7293867d453547be9104bbc4745c9a54.setOption(option_7293867d453547be9104bbc4745c9a54);
#         });
#     </script>

# %%
# 국적별 pie chart
country = list(np.sort(data.country.unique()))
country_value = list(data.country.value_counts().sort_index())

country_plot = (
    Pie()
    .add("", [list(z) for z in zip(country, country_value)])
    .set_colors(['#b09880', '#f0d0c8']) 
    .set_global_opts(title_opts=opts.TitleOpts(title="국적"))
    .set_series_opts(label_opts=opts.LabelOpts(color=["black"], formatter="{b}: {d}%")) #d:%, c:명수
)
country_plot.render()
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\render.html'

# %%
country_plot.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7950439cf92741b0b3b6a66f2fba64d9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7950439cf92741b0b3b6a66f2fba64d9 = echarts.init(
#                     document.getElementById('7950439cf92741b0b3b6a66f2fba64d9'), 'white', {renderer: 'canvas'});
#                 var option_7950439cf92741b0b3b6a66f2fba64d9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#b09880",
#         "#f0d0c8"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uc911\uad6d",
#                     "value": 6
#                 },
#                 {
#                     "name": "\ud55c\uad6d",
#                     "value": 23
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8,
#                 "formatter": "{b}: {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uc911\uad6d",
#                 "\ud55c\uad6d"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\uad6d\uc801",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7950439cf92741b0b3b6a66f2fba64d9.setOption(option_7950439cf92741b0b3b6a66f2fba64d9);
#         });
#     </script>
