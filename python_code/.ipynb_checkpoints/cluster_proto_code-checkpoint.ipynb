# %%
import plotly.figure_factory as ff
import plotly.graph_objs as go
import plotly.io as pio

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
동선 = pd.read_csv("동선정보.csv")

# %%
동선.head()
# Out:
#     timestamp 환자ID 감염 차수  ...         위도          경도                 설명
# 0         NaN  NaN   NaN  ...        NaN         NaN                NaN
# 1         NaN  NaN   NaN  ...        NaN         NaN                NaN
# 2  2020-01-19    1    1차  ...  37.472503  126.431380                NaN
# 3  2020-01-19    1    1차  ...  37.478526  126.666315  공항 검역대에서 바로 격리 조치
# 4  2020-01-22    2    1차  ...  37.560363  126.776299                NaN
#
# [5 rows x 9 columns]

# %%
동선 = 동선.shift(-2)

# %%
동선.tail(17)
# Out:
#     timestamp 환자ID 감염 차수 시(특별/광역)/도 시/구/군  장소명  위도  경도   설명
# 139       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 140       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 141       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 142       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 143       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 144       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 145       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 146       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 147       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 148       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 149       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 150       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 151       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 152       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 153       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 154       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN
# 155       NaN  NaN   NaN        NaN   NaN  NaN NaN NaN  NaN

# %%
동선 = 동선.iloc[:-17,:]

# %%
동선['감염 차수'].value_counts()
# Out:
# 1차              78
# 2차              34
# 3차 (12번의 부인)    19
# 3차(6번의 부부)       3
# 3차               3
# 2차 (5번의 접촉자)     2
# Name: 감염 차수, dtype: int64

# %%
동선['감염 차수'] = 동선['감염 차수'].str[:2] + ' 감염자'

# %%
import folium
from folium import plugins

# %%
popups = 동선['감염 차수']

# %%
data = 동선[['위도', '경도']]

# %%
data.head()
# Out:
#           위도          경도
# 0  37.472503  126.431380
# 1  37.478526  126.666315
# 2  37.560363  126.776299
# 3  37.567227  126.753371
# 4  37.549605  126.866088

# %%
data.isnull().sum()
# Out:
# 위도    4
# 경도    4
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# 위도    0
# 경도    0
# dtype: int64

# %%
m = folium.Map([37.5650172,126.8494648], zoom_start = 10)
plugins.MarkerCluster(data[['위도','경도']].values, popups = popups).add_to(m)

m.save('My Drive')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
