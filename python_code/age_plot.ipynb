# %%
import pandas as pd
import numpy as np
import pyecharts
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
data_path = 'patient_data.csv'
data = pd.read_csv(data_path,  encoding = 'euc-kr')

# %%
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note  \
# 0  2020-01-20   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국  NaN
# 1  2020-01-24   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국  NaN
# 2  2020-01-26   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국  NaN
# 3  2020-01-27   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국  NaN
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국  NaN
#
#    출생년도  나이
# 0   NaN NaN
# 1   NaN NaN
# 2   NaN NaN
# 3   NaN NaN
# 4   NaN NaN

# %%
data = data.fillna("")
data.head()
# Out:
#          date  ID degree hospital condition sex     type  age country note  \
# 0  2020-01-20   1     1차    인천의료원        퇴원   여  중국인 관광객  30대      중국
# 1  2020-01-24   2     1차  국립중앙의료원        퇴원   남    우한 교민  50대      한국
# 2  2020-01-26   3     1차   일산명지병원        퇴원   남    우한 교민  50대      한국
# 3  2020-01-27   4     1차  분당서울대병원        퇴원   남   우한 방문자  50대      한국
# 4  2020-01-30   5     1차    서울의료원        입원   남   우한 방문자  30대      한국
#
#   출생년도 나이
# 0
# 1
# 2
# 3
# 4

# %%
age = list(np.sort(data.age.unique()))
age_value = list(data.age.value_counts().sort_index())

# %%
age_bar = (
        Bar()
        .add_xaxis(age)
        .add_yaxis("확진자 수(명)", age_value, color="#BDBDBD")
        .set_global_opts(title_opts=opts.TitleOpts(title=""))
        .set_series_opts(label_opts=opts.LabelOpts(position="right", color=["black"]))
        .reversal_axis()
)

# %%
age_bar.render('age.html')
# Out:
# 'C:\\Users\\ilove\\Desktop\\KU-BIG\\corocoro\\age.html'

# %%
age_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="06a17e63db524fdb9b2090ba362806da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_06a17e63db524fdb9b2090ba362806da = echarts.init(
#                     document.getElementById('06a17e63db524fdb9b2090ba362806da'), 'white', {renderer: 'canvas'});
#                 var option_06a17e63db524fdb9b2090ba362806da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#BDBDBD",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\ud655\uc9c4\uc790 \uc218(\uba85)",
#             "data": [
#                 1,
#                 10,
#                 6,
#                 10,
#                 11,
#                 5,
#                 2,
#                 1
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "color": [
#                     "black"
#                 ],
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\ud655\uc9c4\uc790 \uc218(\uba85)"
#             ],
#             "selected": {
#                 "\ud655\uc9c4\uc790 \uc218(\uba85)": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "10\ub300",
#                 "20\ub300",
#                 "30\ub300",
#                 "40\ub300",
#                 "50\ub300",
#                 "60\ub300",
#                 "70\ub300",
#                 "80\ub300"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_06a17e63db524fdb9b2090ba362806da.setOption(option_06a17e63db524fdb9b2090ba362806da);
#         });
#     </script>
